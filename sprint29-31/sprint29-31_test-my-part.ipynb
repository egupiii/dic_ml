# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

from pyocr_classification import classify_products

# %%
# Correct labels

labels = ["pocari", "calpis", "ilohas_normal", "ilohas_peach", "tropicana"]

# %% [markdown]
# ## pocari.jpeg

# %%
# Show a test image

im = Image.open("pyocr-images/pocari.jpeg", "r")
plt.imshow(np.array(im))

plt.show()

# %%
# Validate

index = classify_products("pyocr-images/pocari.jpeg")

print(index)
if index is not None:
    print(labels[index])
# Out:
# None

# %% [markdown]
# ## calpis.jpeg

# %%
# Show a test image

im = Image.open("pyocr-images/calpis.jpeg", "r")
plt.imshow(np.array(im))

plt.show()

# %%
# Validate

index = classify_products("pyocr-images/calpis.jpeg")

print(index)
if index is not None:
    print(labels[index])
# Out:
# None

# %% [markdown]
# ## tropicana.jpeg

# %%
# Show a test image

im = Image.open("pyocr-images/tropicana.jpeg", "r")
plt.imshow(np.array(im))

plt.show()

# %%
# Validate

index = classify_products("pyocr-images/tropicana.jpeg")

print(index)
if index is not None:
    print(labels[index])
# Out:
# 1
# calpis
