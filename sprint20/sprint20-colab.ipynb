# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3c3bd4cc-95b7-40ff-a5f7-2eeb0a103f5b" name="files[]" multiple disabled />
#      <output id="result-3c3bd4cc-95b7-40ff-a5f7-2eeb0a103f5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"kegusa","key":"de5d92d59cc4312bdc0a434faae64ccd"}'}

# %%
# Set the path

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# Install Kaggle

# !pip install kaggle

# %%
# Access permission

# !chmod 600 /root/.kaggle/kaggle.json

# %%
# Download a dataset on Kaggle

# !kaggle competitions download -c tgs-salt-identification-challenge
# Out:
# depths.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Install Keras

# !pip install -q keras

# %%
# Clone

# !git clone https://github.com/zhixuhao/unet.git
# Out:
# Cloning into 'unet'...
# remote: Enumerating objects: 394, done.
# remote: Total 394 (delta 0), reused 0 (delta 0), pack-reused 394
# Receiving objects: 100% (394/394), 44.91 MiB | 27.59 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
pwd
# Out:
# '/content'

# %%
mkdir train

# %%
# Unzip a train dataset

# !unzip train.zip -d train
# Out:
# Archive:  train.zip
#    creating: train/images/
#    creating: train/masks/
#   inflating: train/images/8d08955cdf.png
#   inflating: train/images/e045664b46.png
#   inflating: train/images/4989c6509e.png
#   inflating: train/images/fff4eb4941.png
#   inflating: train/images/3a310860a3.png
#   inflating: train/images/7a696bb878.png
#   inflating: train/images/8d3ee9356b.png
#   inflating: train/images/213e0a9f7b.png
#   inflating: train/images/78f17697f2.png
#   inflating: train/images/bd20d18369.png
#   inflating: train/images/de08c5a3b7.png
#   inflating: train/images/f06ef6c8b7.png
#   inflating: train/images/b2d02516e1.png
#   inflating: train/images/5edb37f5a8.png
#   inflating: train/images/b1f0e104f5.png
#   inflating: train/images/40e8e14e60.png
#   inflating: train/images/6e1444d88d.png
#   inflating: train/images/f342603c76.png
#   inflating: train/images/7ba58ee1be.png
#   inflating: train/images/14a89a1840.png
#   inflating: train/images/4319885cf1.png
# ...

# %%
cd unet
# Out:
# /content/unet

# %%
from model import *
from data import *

# %%
# Fit

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'../train/','images','masks',data_gen_args,save_to_dir=None)
model = unet()
model_checkpoint = ModelCheckpoint('unet_salt_identification.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=2000,epochs=5,callbacks=[model_checkpoint])
# Out:
# /content/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# Epoch 1/5
# Found 4000 images belonging to 1 classes.
# Found 4000 images belonging to 1 classes.
# 2000/2000 [==============================] - 855s 428ms/step - loss: 0.5451 - acc: 0.7523
#
# Epoch 00001: loss improved from inf to 0.54513, saving model to unet_salt_identification.hdf5
# Epoch 2/5
# 2000/2000 [==============================] - 843s 421ms/step - loss: 0.4447 - acc: 0.7869
#
# Epoch 00002: loss improved from 0.54513 to 0.44467, saving model to unet_salt_identification.hdf5
# Epoch 3/5
# 2000/2000 [==============================] - 842s 421ms/step - loss: 0.3546 - acc: 0.8635
#
# Epoch 00003: loss improved from 0.44467 to 0.35457, saving model to unet_salt_identification.hdf5
# Epoch 4/5
# 2000/2000 [==============================] - 844s 422ms/step - loss: 0.3084 - acc: 0.8868
#
# ...

# %%
pwd
# Out:
# '/content/unet'

# %%
cd ..
# Out:
# /content

# %%
mkdir test

# %%
# Unzip a test dataset

# !unzip test.zip -d test
# Out:
# Archive:  test.zip
#    creating: test/images/
#   inflating: test/images/8cf16aa0f5.png
#   inflating: test/images/23012be6b7.png
#   inflating: test/images/9e46a3352e.png
#   inflating: test/images/8016056c46.png
#   inflating: test/images/a490a68472.png
#   inflating: test/images/cf19041b8e.png
#   inflating: test/images/a5c02f60cd.png
#   inflating: test/images/631cec82b9.png
#   inflating: test/images/bffa15aaa5.png
#   inflating: test/images/31e17c9459.png
#   inflating: test/images/b695427db8.png
#   inflating: test/images/57b062d234.png
#   inflating: test/images/1705ade299.png
#   inflating: test/images/f1a3d6352e.png
#   inflating: test/images/99e331e803.png
#   inflating: test/images/d343f6974e.png
#   inflating: test/images/068f7a5267.png
#   inflating: test/images/d4c235a41e.png
#   inflating: test/images/bf56f7dd40.png
#   inflating: test/images/6b8b1e7ad6.png
#   inflating: test/images/c268afb4a1.png
#   inflating: test/images/63ed0faeb8.png
# ...

# %%
cd unet
# Out:
# /content/unet

# %%
cd data
# Out:
# /content/unet/data

# %%
mkdir salt_identification

# %%
cd salt_identification
# Out:
# /content/unet/data/salt_identification

# %%
mkdir test

# %%
cd ../..
# Out:
# /content/unet

# %%
# Predict on the test dataset

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
validation_generator = test_datagen.flow_from_directory(
        "../test",
        target_size=(256, 256),
        batch_size=5,
        class_mode=None,
        color_mode='grayscale')
# Out:
# Found 18000 images belonging to 1 classes.

# %%
model = unet()
model.load_weights("unet_salt_identification.hdf5")
results = model.predict_generator(validation_generator,5,verbose=1)
saveResult("data/salt_identification/test",results)
# Out:
# /content/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# 5/5 [==============================] - 5s 995ms/step
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py:132: UserWarning: data/salt_identification/test/6_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py:132: UserWarning: data/salt_identification/test/15_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
from PIL import Image, ImageFilter

im1 = Image.open('data/salt_identification/test/0_predict.png')

# %%
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=256x256 at 0x7F5FEAB337F0>

# %%
# Predict on the train dataset

train_datagen = ImageDataGenerator(rescale=1./255)

# %%
val_generator = train_datagen.flow_from_directory(
        "/content/train",
        target_size=(256, 256),
        batch_size=3,
        class_mode=None,
        color_mode='grayscale',
        classes=["images"],
        shuffle=None)
# Out:
# Found 4000 images belonging to 1 classes.

# %%
cd data/salt_identification
# Out:
# /content/unet/data/salt_identification

# %%
mkdir train

# %%
cd ../..
# Out:
# /content/unet

# %%
model = unet()
model.load_weights("/content/unet/unet_salt_identification.hdf5")
results = model.predict_generator(val_generator,1,verbose=1)
saveResult("/content/unet/data/salt_identification/train",results)
# Out:
# /content/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# 1/1 [==============================] - 3s 3s/step
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py:132: UserWarning: /content/unet/data/salt_identification/train/2_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
image = Image.open('/content/unet/data/salt_identification/train/0_predict.png')

image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=256x256 at 0x7F5FE279F710>

# %%
image_correct = Image.open('/content/train/masks/000e218f21.png')

image_correct
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=101x101 at 0x7F5FE279FF28>

# %%
image2 = Image.open('/content/unet/data/salt_identification/train/1_predict.png')

image2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=256x256 at 0x7F5FE279FC50>

# %%
image2_correct = Image.open('/content/train/masks/003c477d7c.png')

image2_correct
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=101x101 at 0x7F5FE279FDD8>

# %%
image3 = Image.open('/content/unet/data/salt_identification/train/2_predict.png')

image3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=256x256 at 0x7F5FE279FA58>

# %%
image3_correct = Image.open('/content/train/images/00441f1cf2.png')

image3_correct
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=101x101 at 0x7F5FE279FB00>

# %%
# Predict on train dataset without generator

from keras.preprocessing import image
from keras.preprocessing.image import load_img, save_img, img_to_array, array_to_img

# %%
path = "/content/train/images/00441f1cf2.png"
image.load_img(path, grayscale=True, color_mode="rgb", target_size=(256,256))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# <PIL.Image.Image image mode=L size=256x256 at 0x7F5FE2CEBAC8>

# %%
img = load_img(path, grayscale=True, color_mode="rgb", target_size=(256,256))
array = image.img_to_array(img)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
array = array[np.newaxis,:] / 255.

# %%
results = model.predict(array)
saveResult("/content/unet/data/salt_identification/train",results)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py:132: UserWarning: /content/unet/data/salt_identification/train/0_predict.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
path2 = "/content/unet/data/salt_identification/train/0_predict.png"
image.load_img(path2, grayscale=True, color_mode="rgb", target_size=(256,256))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# <PIL.Image.Image image mode=L size=256x256 at 0x7F5FE18CC518>

# %%
path2_correct = "/content/train/masks/00441f1cf2.png"
image.load_img(path2_correct, grayscale=True, color_mode="rgb", target_size=(256,256))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# <PIL.Image.Image image mode=L size=256x256 at 0x7F5FE18949E8>
